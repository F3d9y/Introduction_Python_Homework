# %%
import matplotlib.pyplot as plt

# %%
import random

random.randint(1, 10)
# Out:
# 7

# %%
f = lambda x: random.randint(1, 10)
points = list(map(f, range(1, 10)))
points
# Out:
# [2, 8, 7, 6, 2, 1, 2, 6, 3]

# %%
p = plt.plot(points, 'b.')
