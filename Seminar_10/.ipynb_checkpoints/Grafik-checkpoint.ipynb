# %% [markdown]
# **Общий график функции**

# %%
from sympy import *
from sympy.plotting import plot
from sympy import Interval, Symbol, Solveset
from sympy.calculus.util import *
from sympy import abc
from numpy import arange
from numpy import cos, sin
from scipy import optimize
from scipy.optimize import differential_evolution
init_printing()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1064\2366269922.py in <module>
#       1 from sympy import *
#       2 from sympy.plotting import plot
# ----> 3 from sympy import Interval, Symbol, Solveset
#       4 from sympy.calculus.util import *
#       5 from sympy import abc
#
# ImportError: cannot import name 'Solveset' from 'sympy' (D:\Anaconda\lib\site-packages\sympy\__init__.py)

# %%
def function(x):
    return -12*sin(cos(x))*x**4 - 18*x**3+5*x**2 + 10*x - 30

# %%
x = Symbol('x', real=True)
f = -12*sin(cos(x))*x**4 - 18*x**3+5*x**2 + 10*x - 30
plot(f,(x,-50,))
print(f)
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %% [markdown]
# Выведем график при х ∈ [-8;9]

# %%
plot(f,(x,-8,9))
print(f)
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %% [markdown]
# **Приблизительно 4 корня, найдем точное количество корней:**

# %%
qtyXres = 0
tempXres = function(-10)
for i in arange (-10, 10, 0.001):
    if tempXres * function(i) < 0: qtyXres += 1
    tempXres = function(i)
print(f"Общее кол-во корней = {qtyXres}")
# Out:
# Общее кол-во корней = 6

# %% [markdown]
# **Найдем каждый корень перебором**

# %%
def funcRootResult(minX, maxX, step):
    tempDifferense = 0
    if function(minX) - function(minX + step) < 0:
        for i in arange (minX, maxX, step):
            if function(i) > tempDifferense: 
                nearestX = i
                message = f"Функция возрастает!\nx = {i} => f(x) = {function(i)}\nf(x) = 0 при x = {nsolve(f, nearestX)}"
                return message
    if function(minX) - function(minX + step) > 0:
        for i in arange (minX, maxX, step):
            if function(i) < tempDifferense: 
                nearestX = i
                message = f"Функция убывает!\nx = {i} => f(x) = {function(i)}\nf(x) = 0 при x = {nsolve(f, nearestX)}"
                return message

# %% [markdown]
# **1 корень**

# %%
plot(f,(x,-8,-7))
print(f)
print(funcRootResult(-7.7, -7.6, 0.00001))
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
# Функция убывает!
# x = -7.65062000000187 => f(x) = -0.0876621130482391
# f(x) = 0 при x = -7.65062228513275

# %% [markdown]
# **2 корень:**

# %%
plot(f,(x,-5.5,-4.5))
print(f)
print(funcRootResult(-5.1, -4.9, 0.00001))
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
# Функция возрастает!
# x = -5.026860000002769 => f(x) = 0.0438220023861220
# f(x) = 0 при x = -5.02686592820621

# %% [markdown]
# **3 корень:**

# %%
plot(f,(x,-2,2))
print(f)
print(funcRootResult(-1.5, -1.3, 0.00001))
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
# Функция убывает!
# x = -1.338959999998945 => f(x) = -0.000733721380150598
# f(x) = 0 при x = -1.33896663927711

# %% [markdown]
# **4 корень:**

# %%
plot(f,(x,1.5,3))
print(f)
print(funcRootResult(2.2, 2.3, 0.00001))
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
# Функция возрастает!
# x = 2.273060000000479 => f(x) = 0.000909509824197130
# f(x) = 0 при x = 2.27305684575625

# %% [markdown]
# **5 корень:**

# %%
plot(f,(x,3,5))
print(f)
print(funcRootResult(4.35, 4.4, 0.00001))
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
# Функция убывает!
# x = 4.38352999999873 => f(x) = -0.0231731259884640
# f(x) = 0 при x = 4.38352369796896

# %% [markdown]
# **6 корень:**

# %%
plot(f,(x,7.5,8.5))
print(f)
print(funcRootResult(8, 8.1, 0.00001))
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30
# Функция возрастает!
# x = 8.035169999998669 => f(x) = 0.290239321712306
# f(x) = 0 при x = 8.03516413341352

# %% [markdown]
# **Так как функция является довольно пологой вблизи начала отчета координат, для точного подсчета вершин предлается сжать функцию, умножив все ее коэффициенты на 5**

# %%
ftemp = 5*12*sin(cos(5*x))*x**4 - 5*18*x**3+5*5*x**2 + 5*10*x - 30
plot(ftemp,(x,-2.5,2.5))
print(ftemp)
# Out:
# 60*x**4*sin(cos(5*x)) - 90*x**3 + 25*x**2 + 50*x - 30

# %% [markdown]
# **Уточняем количество вершин:**

# %%
def functionTemp(x):
    return 60*x**4*sin(cos(5*x)) - 90*x**3 + 25*x**2 + 50*x - 30

qtyExtr = 0
check = true
## Кусок кода ниже фактически считает сколько раз функция поменяла свое направление.
for i in arange (-2.5, 2.5, 0.025):
    tempRes = functionTemp(i + 0.025)
    tempY = functionTemp(i)
    if check == true:
        if tempY - tempRes > 0: 
            continue
        else: 
            check == false
            ## print(f"{tempY} < {tempRes}")
            qtyExtr += 1 
            continue
    if check == false:
        if tempY - tempRes < 0: 
            continue
        else:
            check == true
            ## print(f"{tempY} > {tempRes}")
            qtyExtr += 1
            continue
    
print(f"Общее кол-во вершин = {qtyExtr}")
# Out:
# Общее кол-во вершин = 89

# %% [markdown]
# **Одни из вершин**

# %%
def extrFuncValue (func, bMin, bMax):
    bounds = [(bMin, bMax)]
    extrFuncValue = differential_evolution(func, bounds)
    return (extrFuncValue.x,extrFuncValue.fun)

print("Найдены следующие вершины:")
res = extrFuncValue(function, -7, -5) ##границы между x1 и x2 (примерно)
print(f"A ({res[0][0]}, {res[1]})")
res = extrFuncValue(lambda x:-function(x), -5,-1) ##границы между x2 и x3 (примерно)
print(f"B ({res[0][0]}, {res[1] * -1})")
res = extrFuncValue(function, -1, 2) ##границы между x3 и x4 (примерно)
print(f"С ({res[0][0]}, {res[1]})")
res = extrFuncValue(lambda x:-function(x), 2,4) ##границы между x4 и x5 (примерно)
print(f"D ({res[0][0]}, {res[1] * -1})")
res = extrFuncValue(function, 4, 8) ##границы между x5 и x6 (примерно)
print(f"E ({res[0][0]}, {res[1]})")
# Out:
# Найдены следующие вершины:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1064\2771660508.py in <module>
#       5
#       6 print("Найдены следующие вершины:")
# ----> 7 res = extrFuncValue(function, -7, -5) ##границы между x1 и x2 (примерно)
#       8 print(f"A ({res[0][0]}, {res[1]})")
#       9 res = extrFuncValue(lambda x:-function(x), -5,-1) ##границы между x2 и x3 (примерно)
#
# ~\AppData\Local\Temp\ipykernel_1064\2771660508.py in extrFuncValue(func, bMin, bMax)
#       1 def extrFuncValue (func, bMin, bMax):
#       2     bounds = [(bMin, bMax)]
# ----> 3     extrFuncValue = differential_evolution(func, bounds)
#       4     return (extrFuncValue.x,extrFuncValue.fun)
#       5
#
# D:\Anaconda\lib\site-packages\scipy\optimize\_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     390                                      integrality=integrality,
#     391                                      vectorized=vectorized) as solver:
# --> 392         ret = solver.solve()
#     393
#     394     return ret
#
# D:\Anaconda\lib\site-packages\scipy\optimize\_differentialevolution.py in solve(self)
#     982             # only work out population energies for feasible solutions
#     983             self.population_energies[self.feasible] = (
# --> 984                 self._calculate_population_energies(
#     985                     self.population[self.feasible]))
#     986
#
# D:\Anaconda\lib\site-packages\scipy\optimize\_differentialevolution.py in _calculate_population_energies(self, population)
#    1114         parameters_pop = self._scale_parameters(population)
#    1115         try:
# -> 1116             calc_energies = list(
#    1117                 self._mapwrapper(self.func, parameters_pop[0:S])
#    1118             )
#
# D:\Anaconda\lib\site-packages\scipy\_lib\_util.py in __call__(self, x)
#     405
#     406     def __call__(self, x):
# --> 407         return self.f(x, *self.args)
#     408
#     409
#
# ~\AppData\Local\Temp\ipykernel_1064\3346187206.py in function(x)
#       1 def function(x):
# ----> 2     return -12*sin(cos(x))*x**4 - 18*x**3+5*x**2 + 10*x - 30
#
# D:\Anaconda\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#      73                     raise
# ---> 74                 retval = func(*args, **kwargs)
#      75             return retval
#      76
#
# D:\Anaconda\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     474
#     475         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 476         result = super().__new__(cls, *args, **options)
#     477         if evaluate and isinstance(result, cls) and result.args:
#     478             pr2 = min(cls._should_evalf(a) for a in result.args)
#
# D:\Anaconda\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#      73                     raise
# ---> 74                 retval = func(*args, **kwargs)
#      75             return retval
#      76
#
# D:\Anaconda\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     286
#     287         if evaluate:
# --> 288             evaluated = cls.eval(*args)
#     289             if evaluated is not None:
#     290                 return evaluated
#
# D:\Anaconda\lib\site-packages\sympy\functions\elementary\trigonometric.py in eval(cls, arg)
#     594             return cls(-arg)
#     595
# --> 596         i_coeff = arg.as_coefficient(S.ImaginaryUnit)
#     597         if i_coeff is not None:
#     598             return cosh(i_coeff)
#
# AttributeError: 'ImmutableDenseNDimArray' object has no attribute 'as_coefficient'

# %% [markdown]
# **Как минимум 5 вершин на отрезке х ∈ [—10, 10].**
# 1) A (-6.831370038454139, -13820.534926472736)
# 2) B (-4.167783527804093, 3111.3632387359617)
# 3) С (1.7006072772607506, -74.10629308610872)
# 4) D (3.819310836467525, -872.2557702910613)
# 5) E (7.001031654138797, -25610.50968103302)

# %% [markdown]
# **Как минимум 6 интервалов возрастания/убывания ф-ции на отрезке х ∈ [—10, 10].**
# 1) Убывает при x ∈ [-10, -6,83..]
# 2) Возрастает при x ∈ [-6,83.., -4,17..]
# 3) Убывает при x ∈ [-4,17.., 1,7..]
# 4) Возрастает при x ∈ [1,7.., 3,82..]
# 5) Убывает при x ∈ [3,82.., 7,001..]
# 6) Возрастает при x ∈ [7,001.., 9,5]

# %% [markdown]
# **Как минимум 7 промежутков на отрезке х ∈ [—10, 10].**
# *f(x) > 0 на промежутках:*
# x ∈ [-10, -7,65..]
# x ∈ [-5,03.., -1.34..]
# x ∈ [2,27.., 4,38..]
# x ∈ [8,04.., 9,5..]
# *f(x) < 0 на промежутках:*
# x ∈ [-7,65.., -5,03..]
# x ∈ [-1.34.., 2,27..]
# x ∈ [4,38.., 8,04..]
